# %% [markdown]
# <a href="https://colab.research.google.com/github/arthurflor23/handwritten-text-recognition/blob/master/src/tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://github.com/arthurflor23/handwritten-text-recognition/blob/master/doc/image/header.png?raw=true" />
#
# # Handwritten Text Recognition using TensorFlow 2.x
#
# This tutorial shows how you can use the project [Handwritten Text Recognition](https://github.com/arthurflor23/handwritten-text-recognition) in your Google Colab.

# %% [markdown]
# ## 1 Localhost Environment
#
# We'll make sure you have the project in your Google Drive with the datasets in HDF5. If you already have structured files in the cloud, skip this step.

# %% [markdown]
# ### 1.1 Datasets
#
# The datasets that you can use:
#
# a. [Bentham](http://www.transcriptorium.eu/~tsdata/)
#
# b. [IAM](http://www.fki.inf.unibe.ch/databases/iam-handwriting-database)
#
# c. [Rimes](http://www.a2ialab.com/doku.php?id=rimes_database:start)
#
# d. [Saint Gall](https://fki.tic.heia-fr.ch/databases/saint-gall-database)
#
# e. [Washington](https://fki.tic.heia-fr.ch/databases/washington-database)

# %% [markdown]
# ### 1.2 Raw folder
#
# On localhost, download the code project from GitHub and extract the chosen dataset (or all if you prefer) in the **raw** folder. Don't change anything of the structure of the dataset, since the scripts were made from the **original structure** of them. Your project directory will be like this:
#
# ```
# .
# ├── raw
# │   ├── bentham
# │   │   ├── BenthamDatasetR0-GT
# │   │   └── BenthamDatasetR0-Images
# │   ├── iam
# │   │   ├── ascii
# │   │   ├── forms
# │   │   ├── largeWriterIndependentTextLineRecognitionTask
# │   │   ├── lines
# │   │   └── xml
# │   ├── rimes
# │   │   ├── eval_2011
# │   │   ├── eval_2011_annotated.xml
# │   │   ├── training_2011
# │   │   └── training_2011.xml
# │   ├── saintgall
# │   │   ├── data
# │   │   ├── ground_truth
# │   │   ├── README.txt
# │   │   └── sets
# │   └── washington
# │       ├── data
# │       ├── ground_truth
# │       ├── README.txt
# │       └── sets
# └── src
#     ├── data
#     │   ├── evaluation.py
#     │   ├── generator.py
#     │   ├── preproc.py
#     │   ├── reader.py
#     │   ├── similar_error_analysis.py
#     ├── main.py
#     ├── network
#     │   ├── architecture.py
#     │   ├── layers.py
#     │   ├── model.py
#     └── tutorial.ipynb
#
# ```
#
# After that, create virtual environment and install the dependencies with python 3 and pip:
#
# > ```python -m venv .venv && source .venv/bin/activate```
#
# > ```pip install -r requirements.txt```

# %% [markdown]
# ### 1.3 HDF5 files
#
# Now, you'll run the *transform* function from **main.py**. For this, execute on **src** folder:
#
# > ```python main.py --source=<DATASET_NAME> --transform```
#
# Your data will be preprocess and encode, creating and saving in the **data** folder. Now your project directory will be like this:
#
#
# ```
# .
# ├── data
# │   ├── bentham.hdf5
# │   ├── iam.hdf5
# │   ├── rimes.hdf5
# │   ├── saintgall.hdf5
# │   └── washington.hdf5
# ├── raw
# │   ├── bentham
# │   │   ├── BenthamDatasetR0-GT
# │   │   └── BenthamDatasetR0-Images
# │   ├── iam
# │   │   ├── ascii
# │   │   ├── forms
# │   │   ├── largeWriterIndependentTextLineRecognitionTask
# │   │   ├── lines
# │   │   └── xml
# │   ├── rimes
# │   │   ├── eval_2011
# │   │   ├── eval_2011_annotated.xml
# │   │   ├── training_2011
# │   │   └── training_2011.xml
# │   ├── saintgall
# │   │   ├── data
# │   │   ├── ground_truth
# │   │   ├── README.txt
# │   │   └── sets
# │   └── washington
# │       ├── data
# │       ├── ground_truth
# │       ├── README.txt
# │       └── sets
# └── src
#     ├── data
#     │   ├── evaluation.py
#     │   ├── generator.py
#     │   ├── preproc.py
#     │   ├── reader.py
#     │   ├── similar_error_analysis.py
#     ├── main.py
#     ├── network
#     │   ├── architecture.py
#     │   ├── layers.py
#     │   ├── model.py
#     └── tutorial.ipynb
#
# ```
#
# Then upload the **data** and **src** folders in the same directory in your Google Drive.

# %% [markdown]
# ## 2 Google Drive Environment

# %% [markdown]
# ### 2.1 TensorFlow 2.x

# %% [markdown]
# Make sure the jupyter notebook is using GPU mode.

# %%
# !nvidia-smi
# Out:
# Tue Jan 24 08:53:37 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   70C    P0    30W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# %tensorflow_version 2.x
import tensorflow as tf

device_name = tf.test.gpu_device_name()

if device_name != "/device:GPU:0":
    raise SystemError("GPU device not found")

print("Found GPU at: {}".format(device_name))
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.
# Found GPU at: /device:GPU:0

# %% [markdown]
# ### 2.2 Google Drive

# %% [markdown]
# Mount your Google Drive partition.
#
# **Note:** *\"Colab Notebooks/handwritten-text-recognition/src/\"* was the directory where you put the project folders, specifically the **src** folder.

# %%
from google.colab import drive

drive.mount("./gdrive", force_remount=True)

# %cd "./gdrive/My Drive/handwritten-text-recognition_3/src/"
# !ls -l
# Out:
# Mounted at ./gdrive
# /content/gdrive/My Drive/handwritten-text-recognition_3/src
# total 443
# drwx------ 2 root root   4096 Jul 26 15:49 data
# drwx------ 2 root root   4096 Jul 26 15:49 language
# -rw------- 1 root root  11223 Apr 15  2022 main.py
# drwx------ 2 root root   4096 Jul 26 15:49 network
# -rw------- 1 root root 429863 Jan 24 08:54 tutorial.ipynb

# %% [markdown]
# After mount, you can see the list os files in the project folder.

# %% [markdown]
# ## 3 Set Python Classes

# %% [markdown]
# ### 3.1 Environment

# %% [markdown]
# First, let's define our environment variables.
#
# Set the main configuration parameters, like input size, batch size, number of epochs and list of characters. This make compatible with **main.py** and jupyter notebook:
#
# * **dataset**: "bentham", "iam", "rimes", "saintgall", "washington"
#
# * **arch**: network to run: "bluche", "puigcerver", "flor"
#
# * **epochs**: number of epochs
#
# * **batch_size**: number size of the batch

# %%
import os
import datetime
import string

# define parameters
source = "berney_nb_inference"
arch = "flor"
epochs = 200
batch_size = 16

# define paths
source_path = os.path.join("..", "data", f"{source}.hdf5")
output_path = os.path.join("..", "output", source, arch)
target_path = os.path.join(output_path, "checkpoint_weights.hdf5")
os.makedirs(output_path, exist_ok=True)

# define input size, number max of chars per line and list of valid chars
input_size = (1024, 128, 1)
max_text_length = 128
charset_base = string.printable[:95]

print("source:", source_path)
print("output", output_path)
print("target", target_path)
print("charset:", charset_base)
# Out:
# source: ../data/berney_nb_inference.hdf5
# output ../output/berney_nb_inference/flor
# target ../output/berney_nb_inference/flor/checkpoint_weights.hdf5
# charset: 0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %% [markdown]
# ### 3.2 DataGenerator Class

# %% [markdown]
# The second class is **DataGenerator()**, responsible for:
#
# * Load the dataset partitions (train, valid, test);
#
# * Manager batchs for train/validation/test process.

# %%
from data.generator import DataGenerator

dtgen = DataGenerator(source=source_path,
                      batch_size=batch_size,
                      charset=charset_base,
                      max_text_length=max_text_length)

print(f"Train images: {dtgen.size['train']}")
print(f"Validation images: {dtgen.size['valid']}")
print(f"Test images: {dtgen.size['test']}")
# Out:
# Train images: 509
# Validation images: 53
# Test images: 7583

# %% [markdown]
# ### 3.3 HTRModel Class

# %% [markdown]
# The third class is **HTRModel()**, was developed to be easy to use and to abstract the complicated flow of a HTR system. It's responsible for:
#
# * Create model with Handwritten Text Recognition flow, in which calculate the loss function by CTC and decode output to calculate the HTR metrics (CER, WER and SER);
#
# * Save and load model;
#
# * Load weights in the models (train/infer);
#
# * Make Train/Predict process using *generator*.
#
# To make a dynamic HTRModel, its parameters are the *architecture*, *input_size* and *vocab_size*.

# %%
from network.model import HTRModel

# create and compile HTRModel
model = HTRModel(architecture=arch,
                 input_size=input_size,
                 vocab_size=dtgen.tokenizer.vocab_size,
                 beam_width=10,
                 stop_tolerance=50, #20
                 reduce_tolerance=20) #15

model.compile(learning_rate=0.001)
model.summary(output_path, "summary.txt")

# get default callbacks and load checkpoint weights file (HDF5) if exists
model.load_checkpoint(target=target_path)

callbacks = model.get_callbacks(logdir=output_path, checkpoint=target_path, verbose=1)
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 1024, 128, 1)]    0
#
#  conv2d_12 (Conv2D)          (None, 512, 64, 16)       160
#
#  p_re_lu_12 (PReLU)          (None, 512, 64, 16)       16
#
#  batch_normalization_12 (Bat  (None, 512, 64, 16)      112
#  chNormalization)
#
#  full_gated_conv2d_10 (FullG  (None, 512, 64, 16)      4640
#  atedConv2D)
#
#  conv2d_13 (Conv2D)          (None, 512, 64, 32)       4640
#
#  p_re_lu_13 (PReLU)          (None, 512, 64, 32)       32
#
#  batch_normalization_13 (Bat  (None, 512, 64, 32)      224
#  chNormalization)
#
#  full_gated_conv2d_11 (FullG  (None, 512, 64, 32)      18496
#  atedConv2D)
#
#  conv2d_14 (Conv2D)          (None, 256, 16, 40)       10280
#
#  p_re_lu_14 (PReLU)          (None, 256, 16, 40)       40
#
#  batch_normalization_14 (Bat  (None, 256, 16, 40)      280
#  chNormalization)
#
#  full_gated_conv2d_12 (FullG  (None, 256, 16, 40)      28880
#  atedConv2D)
#
#  dropout_6 (Dropout)         (None, 256, 16, 40)       0
#
#  conv2d_15 (Conv2D)          (None, 256, 16, 48)       17328
#
#  p_re_lu_15 (PReLU)          (None, 256, 16, 48)       48
#
#  batch_normalization_15 (Bat  (None, 256, 16, 48)      336
#  chNormalization)
#
#  full_gated_conv2d_13 (FullG  (None, 256, 16, 48)      41568
#  atedConv2D)
#
#  dropout_7 (Dropout)         (None, 256, 16, 48)       0
#
#  conv2d_16 (Conv2D)          (None, 128, 4, 56)        21560
#
#  p_re_lu_16 (PReLU)          (None, 128, 4, 56)        56
#
#  batch_normalization_16 (Bat  (None, 128, 4, 56)       392
#  chNormalization)
#
#  full_gated_conv2d_14 (FullG  (None, 128, 4, 56)       56560
#  atedConv2D)
#
#  dropout_8 (Dropout)         (None, 128, 4, 56)        0
#
#  conv2d_17 (Conv2D)          (None, 128, 4, 64)        32320
#
#  p_re_lu_17 (PReLU)          (None, 128, 4, 64)        64
#
#  batch_normalization_17 (Bat  (None, 128, 4, 64)       448
#  chNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 128, 2, 64)       0
#  2D)
#
#  reshape_2 (Reshape)         (None, 128, 128)          0
#
#  bidirectional_4 (Bidirectio  (None, 128, 256)         198144
#  nal)
#
#  dense_4 (Dense)             (None, 128, 256)          65792
#
#  bidirectional_5 (Bidirectio  (None, 128, 256)         296448
#  nal)
#
#  dense_5 (Dense)             (None, 128, 98)           25186
#
# =================================================================
# Total params: 824,050
# Trainable params: 822,770
# Non-trainable params: 1,280
# _________________________________________________________________

# %% [markdown]
# ## 4 Training

# %% [markdown]
# The training process is similar to the *fit()* of the Keras. After training, the information (epochs and minimum loss) is save.

# %%
# to calculate total and average time per epoch
start_time = datetime.datetime.now()

h = model.fit(x=dtgen.next_train_batch(),
              epochs=epochs,
              steps_per_epoch=dtgen.steps['train'],
              validation_data=dtgen.next_valid_batch(),
              validation_steps=dtgen.steps['valid'],
              callbacks=callbacks,
              shuffle=True,
              verbose=1)

total_time = datetime.datetime.now() - start_time

loss = h.history['loss']
val_loss = h.history['val_loss']

min_val_loss = min(val_loss)
min_val_loss_i = val_loss.index(min_val_loss)

time_epoch = (total_time / len(loss))
total_item = (dtgen.size['train'] + dtgen.size['valid'])

t_corpus = "\n".join([
    f"Total train images:      {dtgen.size['train']}",
    f"Total validation images: {dtgen.size['valid']}",
    f"Batch:                   {dtgen.batch_size}\n",
    f"Total time:              {total_time}",
    f"Time per epoch:          {time_epoch}",
    f"Time per item:           {time_epoch / total_item}\n",
    f"Total epochs:            {len(loss)}",
    f"Best epoch               {min_val_loss_i + 1}\n",
    f"Training loss:           {loss[min_val_loss_i]:.8f}",
    f"Validation loss:         {min_val_loss:.8f}"
])

with open(os.path.join(output_path, "train.txt"), "w") as lg:
    lg.write(t_corpus)
    print(t_corpus)
# Out:
# Epoch 1/200
# 28/28 [==============================] - ETA: 0s - loss: 46.7156
# Epoch 1: val_loss improved from inf to 10.10164, saving model to ../output/berney_nb/flor/checkpoint_weights.hdf5
# 28/28 [==============================] - 29s 315ms/step - loss: 46.7156 - val_loss: 10.1016 - lr: 0.0010
# Epoch 2/200
# 28/28 [==============================] - ETA: 0s - loss: 7.5565
# Epoch 2: val_loss improved from 10.10164 to 7.37556, saving model to ../output/berney_nb/flor/checkpoint_weights.hdf5
# 28/28 [==============================] - 5s 186ms/step - loss: 7.5565 - val_loss: 7.3756 - lr: 0.0010
# Epoch 3/200
# 28/28 [==============================] - ETA: 0s - loss: 7.2556
# Epoch 3: val_loss improved from 7.37556 to 7.14937, saving model to ../output/berney_nb/flor/checkpoint_weights.hdf5
# 28/28 [==============================] - 5s 188ms/step - loss: 7.2556 - val_loss: 7.1494 - lr: 0.0010
# Epoch 4/200
# 28/28 [==============================] - ETA: 0s - loss: 7.1973
# Epoch 4: val_loss did not improve from 7.14937
# 28/28 [==============================] - 5s 183ms/step - loss: 7.1973 - val_loss: 19.8525 - lr: 0.0010
# Epoch 5/200
# 28/28 [==============================] - ETA: 0s - loss: 31.0189
# Epoch 5: val_loss did not improve from 7.14937
# 28/28 [==============================] - 5s 181ms/step - loss: 31.0189 - val_loss: 7.3689 - lr: 0.0010
# Epoch 6/200
# 28/28 [==============================] - ETA: 0s - loss: 7.0458
# Epoch 6: val_loss did not improve from 7.14937
# 28/28 [==============================] - 5s 183ms/step - loss: 7.0458 - val_loss: 7.7725 - lr: 0.0010
# Epoch 7/200
# 28/28 [==============================] - ETA: 0s - loss: 7.0601
# Epoch 7: val_loss improved from 7.14937 to 6.97983, saving model to ../output/berney_nb/flor/checkpoint_weights.hdf5
# 28/28 [==============================] - 6s 220ms/step - loss: 7.0601 - val_loss: 6.9798 - lr: 0.0010
# Epoch 8/200
# 28/28 [==============================] - ETA: 0s - loss: 7.0217
# Epoch 8: val_loss improved from 6.97983 to 6.95442, saving model to ../output/berney_nb/flor/checkpoint_weights.hdf5
# 28/28 [==============================] - 5s 186ms/step - loss: 7.0217 - val_loss: 6.9544 - lr: 0.0010
# Epoch 9/200
# 28/28 [==============================] - ETA: 0s - loss: 6.9156
# Epoch 9: val_loss did not improve from 6.95442
# 28/28 [==============================] - 5s 181ms/step - loss: 6.9156 - val_loss: 7.0617 - lr: 0.0010
# Epoch 10/200
# 28/28 [==============================] - ETA: 0s - loss: 6.9078
# Epoch 10: val_loss did not improve from 6.95442
# 28/28 [==============================] - 5s 180ms/step - loss: 6.9078 - val_loss: 7.2592 - lr: 0.0010
# Epoch 11/200
# 28/28 [==============================] - ETA: 0s - loss: 6.6745
# Epoch 11: val_loss improved from 6.95442 to 6.64133, saving model to ../output/berney_nb/flor/checkpoint_weights.hdf5
# 28/28 [==============================] - 6s 230ms/step - loss: 6.6745 - val_loss: 6.6413 - lr: 0.0010
# Epoch 12/200
# 28/28 [==============================] - ETA: 0s - loss: 6.5506
# Epoch 12: val_loss improved from 6.64133 to 6.41863, saving model to ../output/berney_nb/flor/checkpoint_weights.hdf5
# 28/28 [==============================] - 5s 185ms/step - loss: 6.5506 - val_loss: 6.4186 - lr: 0.0010
# Epoch 13/200
# 28/28 [==============================] - ETA: 0s - loss: 6.5512
# Epoch 13: val_loss did not improve from 6.41863
# 28/28 [==============================] - 5s 179ms/step - loss: 6.5512 - val_loss: 6.4503 - lr: 0.0010
# Epoch 14/200
# 28/28 [==============================] - ETA: 0s - loss: 6.3969
# Epoch 14: val_loss improved from 6.41863 to 6.40737, saving model to ../output/berney_nb/flor/checkpoint_weights.hdf5
# 28/28 [==============================] - 5s 186ms/step - loss: 6.3969 - val_loss: 6.4074 - lr: 0.0010
# Epoch 15/200
# 28/28 [==============================] - ETA: 0s - loss: 6.2539
# Epoch 15: val_loss improved from 6.40737 to 5.94679, saving model to ../output/berney_nb/flor/checkpoint_weights.hdf5
# 28/28 [==============================] - 5s 185ms/step - loss: 6.2539 - val_loss: 5.9468 - lr: 0.0010
# Epoch 16/200
# 28/28 [==============================] - ETA: 0s - loss: 6.2636
# Epoch 16: val_loss did not improve from 5.94679
# 28/28 [==============================] - 5s 180ms/step - loss: 6.2636 - val_loss: 6.1630 - lr: 0.0010
# Epoch 17/200
# 28/28 [==============================] - ETA: 0s - loss: 5.9730
# Epoch 17: val_loss did not improve from 5.94679
# 28/28 [==============================] - 5s 180ms/step - loss: 5.9730 - val_loss: 5.9918 - lr: 0.0010
# Epoch 18/200
# 28/28 [==============================] - ETA: 0s - loss: 6.0314
# Epoch 18: val_loss improved from 5.94679 to 5.72232, saving model to ../output/berney_nb/flor/checkpoint_weights.hdf5
# 28/28 [==============================] - 6s 215ms/step - loss: 6.0314 - val_loss: 5.7223 - lr: 0.0010
# Epoch 19/200
# 28/28 [==============================] - ETA: 0s - loss: 5.8447
# Epoch 19: val_loss did not improve from 5.72232
# 28/28 [==============================] - 5s 181ms/step - loss: 5.8447 - val_loss: 6.1501 - lr: 0.0010
# Epoch 20/200
# 28/28 [==============================] - ETA: 0s - loss: 5.4962
# Epoch 20: val_loss did not improve from 5.72232
# 28/28 [==============================] - 5s 182ms/step - loss: 5.4962 - val_loss: 5.8494 - lr: 0.0010
# Epoch 21/200
# 28/28 [==============================] - ETA: 0s - loss: 5.4839
# Epoch 21: val_loss improved from 5.72232 to 5.25979, saving model to ../output/berney_nb/flor/checkpoint_weights.hdf5
# 28/28 [==============================] - 6s 227ms/step - loss: 5.4839 - val_loss: 5.2598 - lr: 0.0010
# Epoch 22/200
# 28/28 [==============================] - ETA: 0s - loss: 5.4416
# Epoch 22: val_loss improved from 5.25979 to 5.09899, saving model to ../output/berney_nb/flor/checkpoint_weights.hdf5
# 28/28 [==============================] - 5s 186ms/step - loss: 5.4416 - val_loss: 5.0990 - lr: 0.0010
# Epoch 23/200
# 28/28 [==============================] - ETA: 0s - loss: 4.9974
# Epoch 23: val_loss improved from 5.09899 to 4.72650, saving model to ../output/berney_nb/flor/checkpoint_weights.hdf5
# 28/28 [==============================] - 5s 187ms/step - loss: 4.9974 - val_loss: 4.7265 - lr: 0.0010
# Epoch 24/200
# 28/28 [==============================] - ETA: 0s - loss: 4.7066
# Epoch 24: val_loss did not improve from 4.72650
# 28/28 [==============================] - 5s 185ms/step - loss: 4.7066 - val_loss: 5.0064 - lr: 0.0010
# Epoch 25/200
# 28/28 [==============================] - ETA: 0s - loss: 4.2895
# Epoch 25: val_loss improved from 4.72650 to 3.78553, saving model to ../output/berney_nb/flor/checkpoint_weights.hdf5
# 28/28 [==============================] - 6s 221ms/step - loss: 4.2895 - val_loss: 3.7855 - lr: 0.0010
# Epoch 26/200
# 28/28 [==============================] - ETA: 0s - loss: 4.0715
# Epoch 26: val_loss improved from 3.78553 to 3.39506, saving model to ../output/berney_nb/flor/checkpoint_weights.hdf5
# 28/28 [==============================] - 5s 185ms/step - loss: 4.0715 - val_loss: 3.3951 - lr: 0.0010
# Epoch 27/200
# 28/28 [==============================] - ETA: 0s - loss: 3.9660
# Epoch 27: val_loss improved from 3.39506 to 3.35988, saving model to ../output/berney_nb/flor/checkpoint_weights.hdf5
# 28/28 [==============================] - 5s 186ms/step - loss: 3.9660 - val_loss: 3.3599 - lr: 0.0010
# Epoch 28/200
# 28/28 [==============================] - ETA: 0s - loss: 3.4017
# Epoch 28: val_loss did not improve from 3.35988
# 28/28 [==============================] - 5s 186ms/step - loss: 3.4017 - val_loss: 3.6466 - lr: 0.0010
# Epoch 29/200
# 28/28 [==============================] - ETA: 0s - loss: 3.4180
# Epoch 29: val_loss improved from 3.35988 to 2.49099, saving model to ../output/berney_nb/flor/checkpoint_weights.hdf5
# 28/28 [==============================] - 5s 187ms/step - loss: 3.4180 - val_loss: 2.4910 - lr: 0.0010
# Epoch 30/200
# 28/28 [==============================] - ETA: 0s - loss: 2.9136
# Epoch 30: val_loss improved from 2.49099 to 2.08338, saving model to ../output/berney_nb/flor/checkpoint_weights.hdf5
# 28/28 [==============================] - 5s 191ms/step - loss: 2.9136 - val_loss: 2.0834 - lr: 0.0010
# Epoch 31/200
# 28/28 [==============================] - ETA: 0s - loss: 2.7750
# Epoch 31: val_loss did not improve from 2.08338
# 28/28 [==============================] - 5s 197ms/step - loss: 2.7750 - val_loss: 2.2196 - lr: 0.0010
# Epoch 32/200
# 28/28 [==============================] - ETA: 0s - loss: 2.5583
# Epoch 32: val_loss improved from 2.08338 to 1.72709, saving model to ../output/berney_nb/flor/checkpoint_weights.hdf5
# 28/28 [==============================] - 6s 226ms/step - loss: 2.5583 - val_loss: 1.7271 - lr: 0.0010
# Epoch 33/200
# 28/28 [==============================] - ETA: 0s - loss: 2.3816
# Epoch 33: val_loss did not improve from 1.72709
# 28/28 [==============================] - 5s 182ms/step - loss: 2.3816 - val_loss: 2.7268 - lr: 0.0010
# Epoch 34/200
# 28/28 [==============================] - ETA: 0s - loss: 2.3430
# Epoch 34: val_loss improved from 1.72709 to 1.69415, saving model to ../output/berney_nb/flor/checkpoint_weights.hdf5
# 28/28 [==============================] - 6s 212ms/step - loss: 2.3430 - val_loss: 1.6941 - lr: 0.0010
# Epoch 35/200
# 28/28 [==============================] - ETA: 0s - loss: 2.0862
# Epoch 35: val_loss improved from 1.69415 to 1.21066, saving model to ../output/berney_nb/flor/checkpoint_weights.hdf5
# 28/28 [==============================] - 5s 185ms/step - loss: 2.0862 - val_loss: 1.2107 - lr: 0.0010
# Epoch 36/200
# 28/28 [==============================] - ETA: 0s - loss: 1.9357
# Epoch 36: val_loss improved from 1.21066 to 1.19068, saving model to ../output/berney_nb/flor/checkpoint_weights.hdf5
# 28/28 [==============================] - 5s 186ms/step - loss: 1.9357 - val_loss: 1.1907 - lr: 0.0010
# Epoch 37/200
# 28/28 [==============================] - ETA: 0s - loss: 1.9282
# Epoch 37: val_loss improved from 1.19068 to 1.01989, saving model to ../output/berney_nb/flor/checkpoint_weights.hdf5
# 28/28 [==============================] - 5s 191ms/step - loss: 1.9282 - val_loss: 1.0199 - lr: 0.0010
# Epoch 38/200
# 28/28 [==============================] - ETA: 0s - loss: 1.5362
# Epoch 38: val_loss did not improve from 1.01989
# 28/28 [==============================] - 5s 188ms/step - loss: 1.5362 - val_loss: 1.0663 - lr: 0.0010
# Epoch 39/200
# 28/28 [==============================] - ETA: 0s - loss: 1.4067
# Epoch 39: val_loss improved from 1.01989 to 0.75970, saving model to ../output/berney_nb/flor/checkpoint_weights.hdf5
# 28/28 [==============================] - 6s 214ms/step - loss: 1.4067 - val_loss: 0.7597 - lr: 0.0010
# Epoch 40/200
# 28/28 [==============================] - ETA: 0s - loss: 1.2954
# Epoch 40: val_loss did not improve from 0.75970
# 28/28 [==============================] - 5s 194ms/step - loss: 1.2954 - val_loss: 0.8110 - lr: 0.0010
# Epoch 41/200
# 28/28 [==============================] - ETA: 0s - loss: 1.3397
# Epoch 41: val_loss improved from 0.75970 to 0.66998, saving model to ../output/berney_nb/flor/checkpoint_weights.hdf5
# 28/28 [==============================] - 6s 230ms/step - loss: 1.3397 - val_loss: 0.6700 - lr: 0.0010
# Epoch 42/200
# 28/28 [==============================] - ETA: 0s - loss: 1.1361
# Epoch 42: val_loss did not improve from 0.66998
# 28/28 [==============================] - 5s 182ms/step - loss: 1.1361 - val_loss: 0.7375 - lr: 0.0010
# Epoch 43/200
# 28/28 [==============================] - ETA: 0s - loss: 1.0451
# Epoch 43: val_loss improved from 0.66998 to 0.59056, saving model to ../output/berney_nb/flor/checkpoint_weights.hdf5
# 28/28 [==============================] - 6s 209ms/step - loss: 1.0451 - val_loss: 0.5906 - lr: 0.0010
# Epoch 44/200
# 28/28 [==============================] - ETA: 0s - loss: 1.0468
# Epoch 44: val_loss improved from 0.59056 to 0.50697, saving model to ../output/berney_nb/flor/checkpoint_weights.hdf5
# 28/28 [==============================] - 5s 190ms/step - loss: 1.0468 - val_loss: 0.5070 - lr: 0.0010
# Epoch 45/200
# 28/28 [==============================] - ETA: 0s - loss: 0.8905
# Epoch 45: val_loss did not improve from 0.50697
# 28/28 [==============================] - 5s 182ms/step - loss: 0.8905 - val_loss: 0.6207 - lr: 0.0010
# Epoch 46/200
# 28/28 [==============================] - ETA: 0s - loss: 0.8839
# Epoch 46: val_loss did not improve from 0.50697
# 28/28 [==============================] - 5s 181ms/step - loss: 0.8839 - val_loss: 0.5842 - lr: 0.0010
# Epoch 47/200
# 28/28 [==============================] - ETA: 0s - loss: 0.8626
# Epoch 47: val_loss improved from 0.50697 to 0.46275, saving model to ../output/berney_nb/flor/checkpoint_weights.hdf5
# 28/28 [==============================] - 6s 207ms/step - loss: 0.8626 - val_loss: 0.4627 - lr: 0.0010
# Epoch 48/200
# 28/28 [==============================] - ETA: 0s - loss: 0.7479
# Epoch 48: val_loss did not improve from 0.46275
# 28/28 [==============================] - 5s 182ms/step - loss: 0.7479 - val_loss: 0.8059 - lr: 0.0010
# Epoch 49/200
# 28/28 [==============================] - ETA: 0s - loss: 0.8981
# Epoch 49: val_loss did not improve from 0.46275
# 28/28 [==============================] - 5s 182ms/step - loss: 0.8981 - val_loss: 0.4953 - lr: 0.0010
# Epoch 50/200
# 28/28 [==============================] - ETA: 0s - loss: 0.6642
# Epoch 50: val_loss did not improve from 0.46275
# 28/28 [==============================] - 5s 180ms/step - loss: 0.6642 - val_loss: 0.4848 - lr: 0.0010
# Epoch 51/200
# 28/28 [==============================] - ETA: 0s - loss: 0.7021
# Epoch 51: val_loss did not improve from 0.46275
# 28/28 [==============================] - 5s 195ms/step - loss: 0.7021 - val_loss: 0.6518 - lr: 0.0010
# Epoch 52/200
# 28/28 [==============================] - ETA: 0s - loss: 0.6311
# Epoch 52: val_loss improved from 0.46275 to 0.27644, saving model to ../output/berney_nb/flor/checkpoint_weights.hdf5
# 28/28 [==============================] - 6s 208ms/step - loss: 0.6311 - val_loss: 0.2764 - lr: 0.0010
# Epoch 53/200
# 28/28 [==============================] - ETA: 0s - loss: 0.7633
# Epoch 53: val_loss did not improve from 0.27644
# 28/28 [==============================] - 5s 183ms/step - loss: 0.7633 - val_loss: 0.3776 - lr: 0.0010
# Epoch 54/200
# 28/28 [==============================] - ETA: 0s - loss: 0.6263
# Epoch 54: val_loss did not improve from 0.27644
# 28/28 [==============================] - 5s 181ms/step - loss: 0.6263 - val_loss: 0.4322 - lr: 0.0010
# Epoch 55/200
# 28/28 [==============================] - ETA: 0s - loss: 0.5761
# Epoch 55: val_loss did not improve from 0.27644
# 28/28 [==============================] - 5s 185ms/step - loss: 0.5761 - val_loss: 0.3250 - lr: 0.0010
# Epoch 56/200
# 28/28 [==============================] - ETA: 0s - loss: 0.5366
# Epoch 56: val_loss did not improve from 0.27644
# 28/28 [==============================] - 5s 181ms/step - loss: 0.5366 - val_loss: 0.2851 - lr: 0.0010
# Epoch 57/200
# 28/28 [==============================] - ETA: 0s - loss: 0.6030
# Epoch 57: val_loss did not improve from 0.27644
# 28/28 [==============================] - 5s 185ms/step - loss: 0.6030 - val_loss: 0.2825 - lr: 0.0010
# Epoch 58/200
# 28/28 [==============================] - ETA: 0s - loss: 0.3924
# Epoch 58: val_loss did not improve from 0.27644
# 28/28 [==============================] - 5s 186ms/step - loss: 0.3924 - val_loss: 0.5377 - lr: 0.0010
# Epoch 59/200
# 28/28 [==============================] - ETA: 0s - loss: 0.5363
# Epoch 59: val_loss did not improve from 0.27644
# 28/28 [==============================] - 5s 182ms/step - loss: 0.5363 - val_loss: 0.4238 - lr: 0.0010
# Epoch 60/200
# 28/28 [==============================] - ETA: 0s - loss: 0.4877
# Epoch 60: val_loss did not improve from 0.27644
# 28/28 [==============================] - 5s 181ms/step - loss: 0.4877 - val_loss: 0.3592 - lr: 0.0010
# Epoch 61/200
# 28/28 [==============================] - ETA: 0s - loss: 0.5156
# Epoch 61: val_loss did not improve from 0.27644
# 28/28 [==============================] - 5s 194ms/step - loss: 0.5156 - val_loss: 0.3511 - lr: 0.0010
# Epoch 62/200
# 28/28 [==============================] - ETA: 0s - loss: 0.5000
# Epoch 62: val_loss did not improve from 0.27644
# 28/28 [==============================] - 5s 187ms/step - loss: 0.5000 - val_loss: 0.4403 - lr: 0.0010
# Epoch 63/200
# 28/28 [==============================] - ETA: 0s - loss: 0.4603
# Epoch 63: val_loss did not improve from 0.27644
# 28/28 [==============================] - 5s 182ms/step - loss: 0.4603 - val_loss: 0.2776 - lr: 0.0010
# Epoch 64/200
# 28/28 [==============================] - ETA: 0s - loss: 0.4819
# Epoch 64: val_loss improved from 0.27644 to 0.23945, saving model to ../output/berney_nb/flor/checkpoint_weights.hdf5
# 28/28 [==============================] - 6s 209ms/step - loss: 0.4819 - val_loss: 0.2394 - lr: 0.0010
# Epoch 65/200
# 28/28 [==============================] - ETA: 0s - loss: 0.4415
# Epoch 65: val_loss did not improve from 0.23945
# 28/28 [==============================] - 5s 186ms/step - loss: 0.4415 - val_loss: 0.3522 - lr: 0.0010
# Epoch 66/200
# 28/28 [==============================] - ETA: 0s - loss: 0.4236
# Epoch 66: val_loss did not improve from 0.23945
# 28/28 [==============================] - 5s 182ms/step - loss: 0.4236 - val_loss: 0.2952 - lr: 0.0010
# Epoch 67/200
# 28/28 [==============================] - ETA: 0s - loss: 0.5581
# Epoch 67: val_loss did not improve from 0.23945
# 28/28 [==============================] - 5s 182ms/step - loss: 0.5581 - val_loss: 0.4083 - lr: 0.0010
# Epoch 68/200
# 28/28 [==============================] - ETA: 0s - loss: 0.4795
# Epoch 68: val_loss did not improve from 0.23945
# 28/28 [==============================] - 5s 181ms/step - loss: 0.4795 - val_loss: 0.5173 - lr: 0.0010
# Epoch 69/200
# 28/28 [==============================] - ETA: 0s - loss: 0.3595
# Epoch 69: val_loss did not improve from 0.23945
# 28/28 [==============================] - 5s 182ms/step - loss: 0.3595 - val_loss: 0.2945 - lr: 0.0010
# Epoch 70/200
# 28/28 [==============================] - ETA: 0s - loss: 0.3170
# Epoch 70: val_loss did not improve from 0.23945
# 28/28 [==============================] - 5s 182ms/step - loss: 0.3170 - val_loss: 0.3237 - lr: 0.0010
# Epoch 71/200
# 28/28 [==============================] - ETA: 0s - loss: 0.2730
# Epoch 71: val_loss did not improve from 0.23945
# 28/28 [==============================] - 5s 194ms/step - loss: 0.2730 - val_loss: 0.2731 - lr: 0.0010
# Epoch 72/200
# 28/28 [==============================] - ETA: 0s - loss: 0.3109
# Epoch 72: val_loss did not improve from 0.23945
# 28/28 [==============================] - 5s 182ms/step - loss: 0.3109 - val_loss: 0.4704 - lr: 0.0010
# Epoch 73/200
# 28/28 [==============================] - ETA: 0s - loss: 1.0873
# Epoch 73: val_loss did not improve from 0.23945
# 28/28 [==============================] - 5s 181ms/step - loss: 1.0873 - val_loss: 0.4252 - lr: 0.0010
# Epoch 74/200
# 28/28 [==============================] - ETA: 0s - loss: 0.2653
# Epoch 74: val_loss did not improve from 0.23945
# 28/28 [==============================] - 5s 181ms/step - loss: 0.2653 - val_loss: 0.3023 - lr: 0.0010
# Epoch 75/200
# 28/28 [==============================] - ETA: 0s - loss: 0.3601
# Epoch 75: val_loss did not improve from 0.23945
# 28/28 [==============================] - 5s 194ms/step - loss: 0.3601 - val_loss: 0.3564 - lr: 0.0010
# Epoch 76/200
# 28/28 [==============================] - ETA: 0s - loss: 0.3125
# Epoch 76: val_loss did not improve from 0.23945
# 28/28 [==============================] - 5s 181ms/step - loss: 0.3125 - val_loss: 0.3208 - lr: 0.0010
# Epoch 77/200
# 28/28 [==============================] - ETA: 0s - loss: 0.2927
# Epoch 77: val_loss improved from 0.23945 to 0.23304, saving model to ../output/berney_nb/flor/checkpoint_weights.hdf5
# 28/28 [==============================] - 6s 208ms/step - loss: 0.2927 - val_loss: 0.2330 - lr: 0.0010
# Epoch 78/200
# 28/28 [==============================] - ETA: 0s - loss: 0.2607
# Epoch 78: val_loss did not improve from 0.23304
# 28/28 [==============================] - 5s 181ms/step - loss: 0.2607 - val_loss: 0.2994 - lr: 0.0010
# Epoch 79/200
# 28/28 [==============================] - ETA: 0s - loss: 0.2920
# Epoch 79: val_loss did not improve from 0.23304
# 28/28 [==============================] - 5s 181ms/step - loss: 0.2920 - val_loss: 0.4766 - lr: 0.0010
# Epoch 80/200
# 28/28 [==============================] - ETA: 0s - loss: 0.2199
# Epoch 80: val_loss did not improve from 0.23304
# 28/28 [==============================] - 5s 181ms/step - loss: 0.2199 - val_loss: 0.3453 - lr: 0.0010
# Epoch 81/200
# 28/28 [==============================] - ETA: 0s - loss: 0.1894
# Epoch 81: val_loss did not improve from 0.23304
# 28/28 [==============================] - 5s 196ms/step - loss: 0.1894 - val_loss: 0.2337 - lr: 0.0010
# Epoch 82/200
# 28/28 [==============================] - ETA: 0s - loss: 0.3092
# Epoch 82: val_loss did not improve from 0.23304
# 28/28 [==============================] - 5s 181ms/step - loss: 0.3092 - val_loss: 0.5055 - lr: 0.0010
# Epoch 83/200
# 28/28 [==============================] - ETA: 0s - loss: 0.2492
# Epoch 83: val_loss did not improve from 0.23304
# 28/28 [==============================] - 5s 183ms/step - loss: 0.2492 - val_loss: 0.3603 - lr: 0.0010
# Epoch 84/200
# 28/28 [==============================] - ETA: 0s - loss: 0.2246
# Epoch 84: val_loss did not improve from 0.23304
# 28/28 [==============================] - 5s 182ms/step - loss: 0.2246 - val_loss: 0.3179 - lr: 0.0010
# Epoch 85/200
# 28/28 [==============================] - ETA: 0s - loss: 0.3147
# Epoch 85: val_loss did not improve from 0.23304
# 28/28 [==============================] - 5s 180ms/step - loss: 0.3147 - val_loss: 0.3863 - lr: 0.0010
# Epoch 86/200
# 28/28 [==============================] - ETA: 0s - loss: 0.1903
# Epoch 86: val_loss did not improve from 0.23304
# 28/28 [==============================] - 5s 184ms/step - loss: 0.1903 - val_loss: 0.3249 - lr: 0.0010
# Epoch 87/200
# 28/28 [==============================] - ETA: 0s - loss: 0.1698
# Epoch 87: val_loss did not improve from 0.23304
# 28/28 [==============================] - 5s 181ms/step - loss: 0.1698 - val_loss: 0.3739 - lr: 0.0010
# Epoch 88/200
# 28/28 [==============================] - ETA: 0s - loss: 0.1583
# Epoch 88: val_loss did not improve from 0.23304
# 28/28 [==============================] - 5s 181ms/step - loss: 0.1583 - val_loss: 0.2549 - lr: 0.0010
# Epoch 89/200
# 28/28 [==============================] - ETA: 0s - loss: 0.2117
# Epoch 89: val_loss did not improve from 0.23304
# 28/28 [==============================] - 5s 187ms/step - loss: 0.2117 - val_loss: 0.4834 - lr: 0.0010
# Epoch 90/200
# 28/28 [==============================] - ETA: 0s - loss: 0.2324
# Epoch 90: val_loss did not improve from 0.23304
# 28/28 [==============================] - 5s 181ms/step - loss: 0.2324 - val_loss: 0.3036 - lr: 0.0010
# Epoch 91/200
# 28/28 [==============================] - ETA: 0s - loss: 0.2908
# Epoch 91: val_loss did not improve from 0.23304
# 28/28 [==============================] - 5s 196ms/step - loss: 0.2908 - val_loss: 0.3216 - lr: 0.0010
# Epoch 92/200
# 28/28 [==============================] - ETA: 0s - loss: 0.3767
# Epoch 92: val_loss did not improve from 0.23304
# 28/28 [==============================] - 5s 183ms/step - loss: 0.3767 - val_loss: 0.4184 - lr: 0.0010
# Epoch 93/200
# 28/28 [==============================] - ETA: 0s - loss: 0.2040
# Epoch 93: val_loss did not improve from 0.23304
# 28/28 [==============================] - 5s 181ms/step - loss: 0.2040 - val_loss: 0.3408 - lr: 0.0010
# Epoch 94/200
# 28/28 [==============================] - ETA: 0s - loss: 0.1659
# Epoch 94: val_loss did not improve from 0.23304
# 28/28 [==============================] - 5s 187ms/step - loss: 0.1659 - val_loss: 0.3137 - lr: 0.0010
# Epoch 95/200
# 28/28 [==============================] - ETA: 0s - loss: 0.1293
# Epoch 95: val_loss improved from 0.23304 to 0.10529, saving model to ../output/berney_nb/flor/checkpoint_weights.hdf5
# 28/28 [==============================] - 6s 207ms/step - loss: 0.1293 - val_loss: 0.1053 - lr: 0.0010
# Epoch 96/200
# 28/28 [==============================] - ETA: 0s - loss: 0.1421
# Epoch 96: val_loss did not improve from 0.10529
# 28/28 [==============================] - 5s 181ms/step - loss: 0.1421 - val_loss: 0.2827 - lr: 0.0010
# Epoch 97/200
# 28/28 [==============================] - ETA: 0s - loss: 0.1944
# Epoch 97: val_loss did not improve from 0.10529
# 28/28 [==============================] - 5s 182ms/step - loss: 0.1944 - val_loss: 0.7490 - lr: 0.0010
# Epoch 98/200
# 28/28 [==============================] - ETA: 0s - loss: 0.1792
# Epoch 98: val_loss did not improve from 0.10529
# 28/28 [==============================] - 5s 182ms/step - loss: 0.1792 - val_loss: 0.3803 - lr: 0.0010
# Epoch 99/200
# 28/28 [==============================] - ETA: 0s - loss: 0.1223
# Epoch 99: val_loss improved from 0.10529 to 0.04059, saving model to ../output/berney_nb/flor/checkpoint_weights.hdf5
# 28/28 [==============================] - 6s 209ms/step - loss: 0.1223 - val_loss: 0.0406 - lr: 0.0010
# Epoch 100/200
# 28/28 [==============================] - ETA: 0s - loss: 0.2302
# Epoch 100: val_loss did not improve from 0.04059
# 28/28 [==============================] - 5s 181ms/step - loss: 0.2302 - val_loss: 0.4609 - lr: 0.0010
# Epoch 101/200
# 28/28 [==============================] - ETA: 0s - loss: 0.2106
# Epoch 101: val_loss did not improve from 0.04059
# 28/28 [==============================] - 5s 196ms/step - loss: 0.2106 - val_loss: 0.3521 - lr: 0.0010
# Epoch 102/200
# 28/28 [==============================] - ETA: 0s - loss: 0.2772
# Epoch 102: val_loss did not improve from 0.04059
# 28/28 [==============================] - 5s 182ms/step - loss: 0.2772 - val_loss: 0.4931 - lr: 0.0010
# Epoch 103/200
# 28/28 [==============================] - ETA: 0s - loss: 0.2307
# Epoch 103: val_loss did not improve from 0.04059
# 28/28 [==============================] - 5s 180ms/step - loss: 0.2307 - val_loss: 0.2545 - lr: 0.0010
# Epoch 104/200
# 28/28 [==============================] - ETA: 0s - loss: 0.1923
# Epoch 104: val_loss did not improve from 0.04059
# 28/28 [==============================] - 5s 183ms/step - loss: 0.1923 - val_loss: 0.4884 - lr: 0.0010
# Epoch 105/200
# 28/28 [==============================] - ETA: 0s - loss: 0.1396
# Epoch 105: val_loss did not improve from 0.04059
# 28/28 [==============================] - 5s 181ms/step - loss: 0.1396 - val_loss: 0.4066 - lr: 0.0010
# Epoch 106/200
# 28/28 [==============================] - ETA: 0s - loss: 0.1389
# Epoch 106: val_loss did not improve from 0.04059
# 28/28 [==============================] - 5s 182ms/step - loss: 0.1389 - val_loss: 0.6719 - lr: 0.0010
# Epoch 107/200
# 28/28 [==============================] - ETA: 0s - loss: 0.1689
# Epoch 107: val_loss did not improve from 0.04059
# 28/28 [==============================] - 5s 182ms/step - loss: 0.1689 - val_loss: 0.2319 - lr: 0.0010
# Epoch 108/200
# 28/28 [==============================] - ETA: 0s - loss: 0.1824
# Epoch 108: val_loss did not improve from 0.04059
# 28/28 [==============================] - 5s 181ms/step - loss: 0.1824 - val_loss: 0.3374 - lr: 0.0010
# Epoch 109/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0942
# Epoch 109: val_loss did not improve from 0.04059
# 28/28 [==============================] - 5s 182ms/step - loss: 0.0942 - val_loss: 0.2565 - lr: 0.0010
# Epoch 110/200
# 28/28 [==============================] - ETA: 0s - loss: 0.1470
# Epoch 110: val_loss did not improve from 0.04059
# 28/28 [==============================] - 5s 191ms/step - loss: 0.1470 - val_loss: 0.4290 - lr: 0.0010
# Epoch 111/200
# 28/28 [==============================] - ETA: 0s - loss: 0.1177
# Epoch 111: val_loss did not improve from 0.04059
# 28/28 [==============================] - 6s 202ms/step - loss: 0.1177 - val_loss: 0.7313 - lr: 0.0010
# Epoch 112/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0590
# Epoch 112: val_loss did not improve from 0.04059
# 28/28 [==============================] - 5s 186ms/step - loss: 0.0590 - val_loss: 0.5985 - lr: 0.0010
# Epoch 113/200
# 28/28 [==============================] - ETA: 0s - loss: 0.5987
# Epoch 113: val_loss did not improve from 0.04059
# 28/28 [==============================] - 5s 182ms/step - loss: 0.5987 - val_loss: 0.5574 - lr: 0.0010
# Epoch 114/200
# 28/28 [==============================] - ETA: 0s - loss: 0.1333
# Epoch 114: val_loss did not improve from 0.04059
# 28/28 [==============================] - 5s 182ms/step - loss: 0.1333 - val_loss: 0.0455 - lr: 0.0010
# Epoch 115/200
# 28/28 [==============================] - ETA: 0s - loss: 0.1710
# Epoch 115: val_loss did not improve from 0.04059
# 28/28 [==============================] - 5s 182ms/step - loss: 0.1710 - val_loss: 0.8561 - lr: 0.0010
# Epoch 116/200
# 28/28 [==============================] - ETA: 0s - loss: 0.1705
# Epoch 116: val_loss did not improve from 0.04059
# 28/28 [==============================] - 5s 187ms/step - loss: 0.1705 - val_loss: 0.3036 - lr: 0.0010
# Epoch 117/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0920
# Epoch 117: val_loss did not improve from 0.04059
# 28/28 [==============================] - 5s 182ms/step - loss: 0.0920 - val_loss: 0.1180 - lr: 0.0010
# Epoch 118/200
# 28/28 [==============================] - ETA: 0s - loss: 0.1758
# Epoch 118: val_loss did not improve from 0.04059
# 28/28 [==============================] - 5s 182ms/step - loss: 0.1758 - val_loss: 0.2553 - lr: 0.0010
# Epoch 119/200
# 28/28 [==============================] - ETA: 0s - loss: 0.1503
# Epoch 119: val_loss did not improve from 0.04059
#
# Epoch 119: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 28/28 [==============================] - 5s 182ms/step - loss: 0.1503 - val_loss: 0.1327 - lr: 0.0010
# Epoch 120/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0598
# Epoch 120: val_loss did not improve from 0.04059
# 28/28 [==============================] - 5s 187ms/step - loss: 0.0598 - val_loss: 0.0747 - lr: 2.0000e-04
# Epoch 121/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0419
# Epoch 121: val_loss did not improve from 0.04059
# 28/28 [==============================] - 5s 196ms/step - loss: 0.0419 - val_loss: 0.1078 - lr: 2.0000e-04
# Epoch 122/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0515
# Epoch 122: val_loss did not improve from 0.04059
# 28/28 [==============================] - 5s 181ms/step - loss: 0.0515 - val_loss: 0.0985 - lr: 2.0000e-04
# Epoch 123/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0318
# Epoch 123: val_loss did not improve from 0.04059
# 28/28 [==============================] - 5s 181ms/step - loss: 0.0318 - val_loss: 0.1273 - lr: 2.0000e-04
# Epoch 124/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0349
# Epoch 124: val_loss did not improve from 0.04059
# 28/28 [==============================] - 5s 184ms/step - loss: 0.0349 - val_loss: 0.1767 - lr: 2.0000e-04
# Epoch 125/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0371
# Epoch 125: val_loss did not improve from 0.04059
# 28/28 [==============================] - 5s 183ms/step - loss: 0.0371 - val_loss: 0.0824 - lr: 2.0000e-04
# Epoch 126/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0271
# Epoch 126: val_loss did not improve from 0.04059
# 28/28 [==============================] - 5s 183ms/step - loss: 0.0271 - val_loss: 0.0499 - lr: 2.0000e-04
# Epoch 127/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0182
# Epoch 127: val_loss did not improve from 0.04059
# 28/28 [==============================] - 5s 180ms/step - loss: 0.0182 - val_loss: 0.0868 - lr: 2.0000e-04
# Epoch 128/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0341
# Epoch 128: val_loss did not improve from 0.04059
# 28/28 [==============================] - 5s 181ms/step - loss: 0.0341 - val_loss: 0.1861 - lr: 2.0000e-04
# Epoch 129/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0337
# Epoch 129: val_loss did not improve from 0.04059
# 28/28 [==============================] - 5s 181ms/step - loss: 0.0337 - val_loss: 0.1933 - lr: 2.0000e-04
# Epoch 130/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0387
# Epoch 130: val_loss did not improve from 0.04059
# 28/28 [==============================] - 5s 187ms/step - loss: 0.0387 - val_loss: 0.2419 - lr: 2.0000e-04
# Epoch 131/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0178
# Epoch 131: val_loss did not improve from 0.04059
# 28/28 [==============================] - 5s 195ms/step - loss: 0.0178 - val_loss: 0.2153 - lr: 2.0000e-04
# Epoch 132/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0216
# Epoch 132: val_loss did not improve from 0.04059
# 28/28 [==============================] - 5s 181ms/step - loss: 0.0216 - val_loss: 0.1340 - lr: 2.0000e-04
# Epoch 133/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0159
# Epoch 133: val_loss did not improve from 0.04059
# 28/28 [==============================] - 5s 182ms/step - loss: 0.0159 - val_loss: 0.1031 - lr: 2.0000e-04
# Epoch 134/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0141
# Epoch 134: val_loss did not improve from 0.04059
# 28/28 [==============================] - 5s 181ms/step - loss: 0.0141 - val_loss: 0.1179 - lr: 2.0000e-04
# Epoch 135/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0335
# Epoch 135: val_loss did not improve from 0.04059
# 28/28 [==============================] - 5s 180ms/step - loss: 0.0335 - val_loss: 0.1704 - lr: 2.0000e-04
# Epoch 136/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0207
# Epoch 136: val_loss did not improve from 0.04059
# 28/28 [==============================] - 5s 181ms/step - loss: 0.0207 - val_loss: 0.1324 - lr: 2.0000e-04
# Epoch 137/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0138
# Epoch 137: val_loss did not improve from 0.04059
# 28/28 [==============================] - 5s 181ms/step - loss: 0.0138 - val_loss: 0.1263 - lr: 2.0000e-04
# Epoch 138/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0230
# Epoch 138: val_loss did not improve from 0.04059
# 28/28 [==============================] - 5s 182ms/step - loss: 0.0230 - val_loss: 0.3130 - lr: 2.0000e-04
# Epoch 139/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0233
# Epoch 139: val_loss did not improve from 0.04059
#
# Epoch 139: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 28/28 [==============================] - 5s 183ms/step - loss: 0.0233 - val_loss: 0.2418 - lr: 2.0000e-04
# Epoch 140/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0143
# Epoch 140: val_loss did not improve from 0.04059
# 28/28 [==============================] - 5s 181ms/step - loss: 0.0143 - val_loss: 0.2401 - lr: 4.0000e-05
# Epoch 141/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0246
# Epoch 141: val_loss did not improve from 0.04059
# 28/28 [==============================] - 5s 195ms/step - loss: 0.0246 - val_loss: 0.2344 - lr: 4.0000e-05
# Epoch 142/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0157
# Epoch 142: val_loss did not improve from 0.04059
# 28/28 [==============================] - 5s 181ms/step - loss: 0.0157 - val_loss: 0.2241 - lr: 4.0000e-05
# Epoch 143/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0108
# Epoch 143: val_loss did not improve from 0.04059
# 28/28 [==============================] - 5s 183ms/step - loss: 0.0108 - val_loss: 0.1973 - lr: 4.0000e-05
# Epoch 144/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0129
# Epoch 144: val_loss did not improve from 0.04059
# 28/28 [==============================] - 5s 180ms/step - loss: 0.0129 - val_loss: 0.1889 - lr: 4.0000e-05
# Epoch 145/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0132
# Epoch 145: val_loss did not improve from 0.04059
# 28/28 [==============================] - 5s 182ms/step - loss: 0.0132 - val_loss: 0.1877 - lr: 4.0000e-05
# Epoch 146/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0224
# Epoch 146: val_loss did not improve from 0.04059
# 28/28 [==============================] - 6s 200ms/step - loss: 0.0224 - val_loss: 0.1740 - lr: 4.0000e-05
# Epoch 147/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0230
# Epoch 147: val_loss did not improve from 0.04059
# 28/28 [==============================] - 5s 182ms/step - loss: 0.0230 - val_loss: 0.1901 - lr: 4.0000e-05
# Epoch 148/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0183
# Epoch 148: val_loss did not improve from 0.04059
# 28/28 [==============================] - 5s 183ms/step - loss: 0.0183 - val_loss: 0.1603 - lr: 4.0000e-05
# Epoch 149/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0114
# Epoch 149: val_loss did not improve from 0.04059
# Restoring model weights from the end of the best epoch: 99.
# 28/28 [==============================] - 5s 184ms/step - loss: 0.0114 - val_loss: 0.1573 - lr: 4.0000e-05
# Epoch 149: early stopping
# Total train images:      447
# Total validation images: 48
# Batch:                   16
#
# Total time:              0:13:26.276202
# Time per epoch:          0:00:05.411250
# Time per item:           0:00:00.010932
#
# Total epochs:            149
# Best epoch               99
#
# Training loss:           0.12234534
# Validation loss:         0.04059058

# %% [markdown]
# ## 5 Predict

# %% [markdown]
# The predict process is similar to the *predict* of the Keras:

# %%
from data import preproc as pp
from google.colab.patches import cv2_imshow

start_time = datetime.datetime.now()

# predict() function will return the predicts with the probabilities
predicts, _ = model.predict(x=dtgen.next_test_batch(),
                            steps=dtgen.steps['test'],
                            ctc_decode=True,
                            verbose=1)

# decode to string
predicts = [dtgen.tokenizer.decode(x[0]) for x in predicts]
ground_truth = [x.decode() for x in dtgen.dataset['test']['gt']]

total_time = datetime.datetime.now() - start_time

# mount predict corpus file
with open(os.path.join(output_path, "predict.txt"), "w") as lg:
    for pd, gt in zip(predicts, ground_truth):
        lg.write(f"TE_L {gt}\nTE_P {pd}\n")
   
for i, item in enumerate(dtgen.dataset['test']['dt'][:100]):
    print("=" * 1024, "\n")
    cv2_imshow(pp.adjust_to_see(item))
    print(ground_truth[i])
    print(predicts[i], "\n")
# Out:
# Model Predict
# 474/474 [==============================] - 22s 47ms/step
# CTC Decode
# 474/474 [==============================] - 465s 980ms/step
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FC14F3B4160>
# 21
# 120
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FC14F3B8EB0>
# 21
# 116
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FC14F349B80>
# 21
# 89
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FC14F346E50>
# 21
# 115
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FC14F3B40A0>
# 21
# 94
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FC14F3B8F40>
# 21
# 108
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FC14F3B40D0>
# 21
# 112
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FC14F3B8F40>
# 21
# 117
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FC14F3B8EB0>
# 21
# 114
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FC14F3B8F40>
# 21
# 102
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FC14F3B8EB0>
# 21
# 91
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FC14F3B8F40>
# 21
# 111
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FC14F3B8EB0>
# 21
# 92
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FC14F3B8F40>
# 21
# 9
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FC14F346DF0>
# 21
# 96
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FC14F3B40D0>
# 21
# 113
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FC14EC56310>
# 21
# 107
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FC14F3B8EB0>
# 21
# 105
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FC14F3B8EB0>
# 21
# 110
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FC14F3B8F40>
# 21
# 103
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FC14EC56310>
# 21
# 118
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FC14F346F70>
# 21
# 9
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FC14F3B4130>
# 21
# 101
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FC14F346DF0>
# 21
# 92
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FC14F3495B0>
# 21
# 106
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FC14F3B8F40>
# 21
# 104
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FC14F346F70>
# 21
# 300
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FC14EC56310>
# 21
# 109
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FC14EC56310>
# 21
# 98
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FC135B5C250>
# 21
# 89
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FC14F3B8EB0>
# 21
# 90
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FC14F3B8F40>
# 21
# 88
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FC14F3B8F40>
# 21
# 87
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FC135B5C250>
# 21
# 80
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FC14F3B8EB0>
# 21
# 86
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FC135B5C250>
# 21
# 81
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FC135B5C250>
# 21
# 9
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FC135B5C250>
# 21
# 7
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FC14F3B8F40>
# 21
# 78
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FC14F3B8F40>
# 21
# 53.2
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FC14F3B8F40>
# 21
# 65
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FC14F3B8F40>
# 21
# 56
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FC14F3BCBB0>
# 21
# 59.2
#
# ...
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FC14F3BCBB0>
# 21
# 44
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FC14F3BCBB0>
# 21
# 46
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FC14F3BCBB0>
# 21
# 13
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FC1BC53ED90>
# 21
# 10
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FC1BC53ED90>
# 21
# 2
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FC1BC53ED90>
# 21
# 9
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FC14F3B45B0>
# 21
# 1
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FC1BC53ED90>
# 21
# 22
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FC1BC53ED90>
# 21
# 23
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FC1BC53ED90>
# 21
# 8
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FC1BC53ED90>
# 21
# 26
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FC1BC53ED90>
# 21
# 14
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FC1BC53ED90>
# 21
# 6
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FC1BC53ED90>
# 21
# 15
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7FC14F3BCBB0>
# 21
# 18

# %% [markdown]
# ## 6 Evaluate

# %% [markdown]
# Evaluation process is more manual process. Here we have the `ocr_metrics`, but feel free to implement other metrics instead. In the function, we have three parameters:
#
# * predicts
# * ground_truth
# * norm_accentuation (calculation with/without accentuation)
# * norm_punctuation (calculation with/without punctuation marks)

# %%
from data import evaluation

evaluate = evaluation.ocr_metrics(predicts, ground_truth)

e_corpus = "\n".join([
    f"Total test images:    {dtgen.size['test']}",
    f"Total time:           {total_time}",
    f"Time per item:        {total_time / dtgen.size['test']}\n",
    f"Metrics:",
    f"Character Error Rate: {evaluate[0]:.8f}",
    f"Word Error Rate:      {evaluate[1]:.8f}",
    f"Sequence Error Rate:  {evaluate[2]:.8f}"
])

with open(os.path.join(output_path, "evaluate.txt"), "w") as lg:
    lg.write(e_corpus)
    print(e_corpus)
# Out:
# Total test images:    25
# Total time:           0:00:03.462598
# Time per item:        0:00:00.138504
#
# Metrics:
# Character Error Rate: 0.04000000
# Word Error Rate:      0.08000000
# Sequence Error Rate:  0.08000000
