# %% [markdown]
# # Handwritten Text Recognition for the Polier notebook
#
# Based on Transkribus Reader and Handwritten Text Recognition using TensorFlow 2.x by arthurflor23 (https://github.com/arthurflor23/handwritten-text-recognition)

# %% [markdown]
# ## 1 Localhost Environment
#
# We'll make sure you have the project in your Google Drive with the datasets in HDF5. If you already have structured files in the cloud, skip this step.

# %% [markdown]
# ### 1.1 Datasets
#
# The datasets that you can use:
#
# a. [Bentham](http://www.transcriptorium.eu/~tsdata/)
#
# b. [IAM](http://www.fki.inf.unibe.ch/databases/iam-handwriting-database)
#
# c. [Rimes](http://www.a2ialab.com/doku.php?id=rimes_database:start)
#
# d. [Saint Gall](https://fki.tic.heia-fr.ch/databases/saint-gall-database)
#
# e. [Washington](https://fki.tic.heia-fr.ch/databases/washington-database)

# %% [markdown]
# ### 1.2 Raw folder
#
# On localhost, download the code project from GitHub and extract the chosen dataset (or all if you prefer) in the **raw** folder. Don't change anything of the structure of the dataset, since the scripts were made from the **original structure** of them. Your project directory will be like this:
#
# ```
# .
# ├── raw
# │   ├── bentham
# │   │   ├── BenthamDatasetR0-GT
# │   │   └── BenthamDatasetR0-Images
# │   ├── iam
# │   │   ├── ascii
# │   │   ├── forms
# │   │   ├── largeWriterIndependentTextLineRecognitionTask
# │   │   ├── lines
# │   │   └── xml
# │   ├── rimes
# │   │   ├── eval_2011
# │   │   ├── eval_2011_annotated.xml
# │   │   ├── training_2011
# │   │   └── training_2011.xml
# │   ├── saintgall
# │   │   ├── data
# │   │   ├── ground_truth
# │   │   ├── README.txt
# │   │   └── sets
# │   └── washington
# │       ├── data
# │       ├── ground_truth
# │       ├── README.txt
# │       └── sets
# └── src
#     ├── data
#     │   ├── evaluation.py
#     │   ├── generator.py
#     │   ├── preproc.py
#     │   ├── reader.py
#     │   ├── similar_error_analysis.py
#     ├── main.py
#     ├── network
#     │   ├── architecture.py
#     │   ├── layers.py
#     │   ├── model.py
#     └── tutorial.ipynb
#
# ```
#
# After that, create virtual environment and install the dependencies with python 3 and pip:
#
# > ```python -m venv .venv && source .venv/bin/activate```
#
# > ```pip install -r requirements.txt```

# %% [markdown]
# ### 1.3 HDF5 files
#
# Now, you'll run the *transform* function from **main.py**. For this, execute on **src** folder:
#
# > ```python main.py --source=<DATASET_NAME> --transform```
#
# Your data will be preprocess and encode, creating and saving in the **data** folder. Now your project directory will be like this:
#
#
# ```
# .
# ├── data
# │   ├── bentham.hdf5
# │   ├── iam.hdf5
# │   ├── rimes.hdf5
# │   ├── saintgall.hdf5
# │   └── washington.hdf5
# ├── raw
# │   ├── bentham
# │   │   ├── BenthamDatasetR0-GT
# │   │   └── BenthamDatasetR0-Images
# │   ├── iam
# │   │   ├── ascii
# │   │   ├── forms
# │   │   ├── largeWriterIndependentTextLineRecognitionTask
# │   │   ├── lines
# │   │   └── xml
# │   ├── rimes
# │   │   ├── eval_2011
# │   │   ├── eval_2011_annotated.xml
# │   │   ├── training_2011
# │   │   └── training_2011.xml
# │   ├── saintgall
# │   │   ├── data
# │   │   ├── ground_truth
# │   │   ├── README.txt
# │   │   └── sets
# │   └── washington
# │       ├── data
# │       ├── ground_truth
# │       ├── README.txt
# │       └── sets
# └── src
#     ├── data
#     │   ├── evaluation.py
#     │   ├── generator.py
#     │   ├── preproc.py
#     │   ├── reader.py
#     │   ├── similar_error_analysis.py
#     ├── main.py
#     ├── network
#     │   ├── architecture.py
#     │   ├── layers.py
#     │   ├── model.py
#     └── tutorial.ipynb
#
# ```
#
# Then upload the **data** and **src** folders in the same directory in your Google Drive.

# %% [markdown]
# ## 2 Google Drive Environment

# %% [markdown]
# ### 2.1 TensorFlow 2.x

# %% [markdown]
# Make sure the jupyter notebook is using GPU mode.

# %%
# !nvidia-smi
# Out:
# Thu Mar 16 10:11:46 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   50C    P0    25W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# %tensorflow_version 2.x
import tensorflow as tf

device_name = tf.test.gpu_device_name()

if device_name != "/device:GPU:0":
    raise SystemError("GPU device not found")

print("Found GPU at: {}".format(device_name))
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.
# Found GPU at: /device:GPU:0

# %% [markdown]
# ### 2.2 Google Drive

# %% [markdown]
# Mount your Google Drive partition.
#
# **Note:** *\"Colab Notebooks/handwritten-text-recognition/src/\"* was the directory where you put the project folders, specifically the **src** folder.

# %%
from google.colab import drive

drive.mount("./gdrive", force_remount=True)

# %cd "./gdrive/My Drive/MASTER_HN/Cahiers Polier/handwritten-text-recognition_polier/src"
# !ls -l
# Out:
# Mounted at ./gdrive
# /content/gdrive/My Drive/MASTER_HN/Cahiers Polier/handwritten-text-recognition_polier/src
# total 78
# drwx------ 2 root root  4096 Nov 11 12:35 data
# drwx------ 2 root root  4096 Nov 13 10:55 language
# -rw------- 1 root root 11223 Apr 15  2022 main.py
# drwx------ 2 root root  4096 Nov 11 12:33 network
# -rw------- 1 root root 55354 Jul 27  2022 tutorial.ipynb

# %% [markdown]
# After mount, you can see the list os files in the project folder.

# %% [markdown]
# ## 3 Set Python Classes

# %% [markdown]
# ### 3.1 Environment

# %% [markdown]
# First, let's define our environment variables.
#
# Set the main configuration parameters, like input size, batch size, number of epochs and list of characters. This make compatible with **main.py** and jupyter notebook:
#
# * **dataset**: "bentham", "iam", "rimes", "saintgall", "washington"
#
# * **arch**: network to run: "bluche", "puigcerver", "flor"
#
# * **epochs**: number of epochs
#
# * **batch_size**: number size of the batch

# %%
import os
import datetime
import string

# modèle de boucle
#for source in ["cahier1", "cahier2", "cahier3"]: # max 40-50 hdf5
# COLLER LES CELLULES 3.1, 3.2, 3.3, 3.5

# define parameters
source = "bentham_v1" # commenter si on fait une boucle
arch = "flor"
epochs = 100
batch_size = 16

# define paths
source_path = os.path.join("..", "data", f"{source}.hdf5")
output_path = os.path.join("..", "output", source, arch)
target_path = os.path.join(output_path, "bentham_train_polier_2.hdf5")
os.makedirs(output_path, exist_ok=True)

# define input size, number max of chars per line and list of valid chars
input_size = (1024, 128, 1)
max_text_length = 128
#charset_base = string.printable[:95]
charset_base = "0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!\"&'()*+,-.:;=?~ éàè"

print("source:", source_path)
print("output", output_path)
print("target", target_path)
print("charset:", charset_base)

# Coller les cellules suivantes (sauf train)
# Out:
# source: ../data/bentham_v1.hdf5
# output ../output/bentham_v1/flor
# target ../output/bentham_v1/flor/bentham_train_polier_2.hdf5
# charset: 0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"&'()*+,-.:;=?~ éàè

# %% [markdown]
# ### 3.2 DataGenerator Class

# %% [markdown]
# The second class is **DataGenerator()**, responsible for:
#
# * Load the dataset partitions (train, valid, test);
#
# * Manager batchs for train/validation/test process.

# %%
from data.generator import *

dtgen = DataGenerator(source=source_path,
                      batch_size=batch_size,
                      charset=charset_base,
                      max_text_length=max_text_length)

print(f"Train images: {dtgen.size['train']}")
print(f"Validation images: {dtgen.size['valid']}")
print(f"Test images: {dtgen.size['test']}")
# Out:
# Train images: 8807
# Validation images: 1372
# Test images: 820

# %% [markdown]
# ### 3.3 HTRModel Class

# %% [markdown]
# The third class is **HTRModel()**, was developed to be easy to use and to abstract the complicated flow of a HTR system. It's responsible for:
#
# * Create model with Handwritten Text Recognition flow, in which calculate the loss function by CTC and decode output to calculate the HTR metrics (CER, WER and SER);
#
# * Save and load model;
#
# * Load weights in the models (train/infer);
#
# * Make Train/Predict process using *generator*.
#
# To make a dynamic HTRModel, its parameters are the *architecture*, *input_size* and *vocab_size*.

# %%
from network.model import HTRModel

# create and compile HTRModel
model = HTRModel(architecture=arch,
                 input_size=input_size,
                 vocab_size=dtgen.tokenizer.vocab_size,
                 beam_width=10,
                 stop_tolerance=20,
                 reduce_tolerance=15)

model.compile(learning_rate=0.001)
model.summary(output_path, "summary.txt")

# get default callbacks and load checkpoint weights file (HDF5) if exists
model.load_checkpoint(target=target_path)

callbacks = model.get_callbacks(logdir=output_path, checkpoint=target_path, verbose=1)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 1024, 128, 1)]    0
#
#  conv2d (Conv2D)             (None, 512, 64, 16)       160
#
#  p_re_lu (PReLU)             (None, 512, 64, 16)       16
#
#  batch_normalization (BatchN  (None, 512, 64, 16)      112
#  ormalization)
#
#  full_gated_conv2d (FullGate  (None, 512, 64, 16)      4640
#  dConv2D)
#
#  conv2d_1 (Conv2D)           (None, 512, 64, 32)       4640
#
#  p_re_lu_1 (PReLU)           (None, 512, 64, 32)       32
#
#  batch_normalization_1 (Batc  (None, 512, 64, 32)      224
#  hNormalization)
#
#  full_gated_conv2d_1 (FullGa  (None, 512, 64, 32)      18496
#  tedConv2D)
#
#  conv2d_2 (Conv2D)           (None, 256, 16, 40)       10280
#
#  p_re_lu_2 (PReLU)           (None, 256, 16, 40)       40
#
#  batch_normalization_2 (Batc  (None, 256, 16, 40)      280
#  hNormalization)
#
#  full_gated_conv2d_2 (FullGa  (None, 256, 16, 40)      28880
#  tedConv2D)
#
#  dropout (Dropout)           (None, 256, 16, 40)       0
#
#  conv2d_3 (Conv2D)           (None, 256, 16, 48)       17328
#
#  p_re_lu_3 (PReLU)           (None, 256, 16, 48)       48
#
#  batch_normalization_3 (Batc  (None, 256, 16, 48)      336
#  hNormalization)
#
#  full_gated_conv2d_3 (FullGa  (None, 256, 16, 48)      41568
#  tedConv2D)
#
#  dropout_1 (Dropout)         (None, 256, 16, 48)       0
#
#  conv2d_4 (Conv2D)           (None, 128, 4, 56)        21560
#
#  p_re_lu_4 (PReLU)           (None, 128, 4, 56)        56
#
#  batch_normalization_4 (Batc  (None, 128, 4, 56)       392
#  hNormalization)
#
#  full_gated_conv2d_4 (FullGa  (None, 128, 4, 56)       56560
#  tedConv2D)
#
#  dropout_2 (Dropout)         (None, 128, 4, 56)        0
#
#  conv2d_5 (Conv2D)           (None, 128, 4, 64)        32320
#
#  p_re_lu_5 (PReLU)           (None, 128, 4, 64)        64
#
#  batch_normalization_5 (Batc  (None, 128, 4, 64)       448
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 128, 2, 64)       0
#  )
#
#  reshape (Reshape)           (None, 128, 128)          0
#
#  bidirectional (Bidirectiona  (None, 128, 256)         198144
#  l)
#
#  dense (Dense)               (None, 128, 256)          65792
#
#  bidirectional_1 (Bidirectio  (None, 128, 256)         296448
#  nal)
#
#  dense_1 (Dense)             (None, 128, 85)           21845
#
# =================================================================
# Total params: 820,709
# Trainable params: 819,429
# Non-trainable params: 1,280
# _________________________________________________________________

# %% [markdown]
# ## 4 Training

# %% [markdown]
# The training process is similar to the *fit()* of the Keras. After training, the information (epochs and minimum loss) is save.

# %%
# to calculate total and average time per epoch
start_time = datetime.datetime.now()

h = model.fit(x=dtgen.next_train_batch(),
              epochs=epochs,
              steps_per_epoch=dtgen.steps['train'],
              validation_data=dtgen.next_valid_batch(),
              validation_steps=dtgen.steps['valid'],
              callbacks=callbacks,
              shuffle=True,
              verbose=1)

total_time = datetime.datetime.now() - start_time

loss = h.history['loss']
val_loss = h.history['val_loss']

min_val_loss = min(val_loss)
min_val_loss_i = val_loss.index(min_val_loss)

time_epoch = (total_time / len(loss))
total_item = (dtgen.size['train'] + dtgen.size['valid'])

t_corpus = "\n".join([
    f"Total train images:      {dtgen.size['train']}",
    f"Total validation images: {dtgen.size['valid']}",
    f"Batch:                   {dtgen.batch_size}\n",
    f"Total time:              {total_time}",
    f"Time per epoch:          {time_epoch}",
    f"Time per item:           {time_epoch / total_item}\n",
    f"Total epochs:            {len(loss)}",
    f"Best epoch               {min_val_loss_i + 1}\n",
    f"Training loss:           {loss[min_val_loss_i]:.8f}",
    f"Validation loss:         {min_val_loss:.8f}"
])

with open(os.path.join(output_path, "train.txt"), "w") as lg:
    lg.write(t_corpus)
    print(t_corpus)
# Out:
# Epoch 1/100
# 551/551 [==============================] - ETA: 0s - loss: 7.0322
# Epoch 1: val_loss improved from inf to 9.70147, saving model to ../output/bentham_v1/flor/bentham_train_polier_2.hdf5
# 551/551 [==============================] - 136s 199ms/step - loss: 7.0322 - val_loss: 9.7015 - lr: 0.0010
# Epoch 2/100
# 551/551 [==============================] - ETA: 0s - loss: 7.0686
# Epoch 2: val_loss improved from 9.70147 to 9.43947, saving model to ../output/bentham_v1/flor/bentham_train_polier_2.hdf5
# 551/551 [==============================] - 107s 195ms/step - loss: 7.0686 - val_loss: 9.4395 - lr: 0.0010
# Epoch 3/100
# 551/551 [==============================] - ETA: 0s - loss: 7.3491
# Epoch 3: val_loss did not improve from 9.43947
# 551/551 [==============================] - 104s 188ms/step - loss: 7.3491 - val_loss: 9.5801 - lr: 0.0010
# Epoch 4/100
# 551/551 [==============================] - ETA: 0s - loss: 7.2826
# Epoch 4: val_loss did not improve from 9.43947
# 551/551 [==============================] - 102s 185ms/step - loss: 7.2826 - val_loss: 9.8473 - lr: 0.0010
# Epoch 5/100
# 551/551 [==============================] - ETA: 0s - loss: 7.4471
# Epoch 5: val_loss improved from 9.43947 to 9.33037, saving model to ../output/bentham_v1/flor/bentham_train_polier_2.hdf5
# 551/551 [==============================] - 104s 188ms/step - loss: 7.4471 - val_loss: 9.3304 - lr: 0.0010
# Epoch 6/100
# 551/551 [==============================] - ETA: 0s - loss: 7.4192
# Epoch 6: val_loss did not improve from 9.33037
# 551/551 [==============================] - 107s 194ms/step - loss: 7.4192 - val_loss: 9.3370 - lr: 0.0010
# Epoch 7/100
# 551/551 [==============================] - ETA: 0s - loss: 7.3100
# Epoch 7: val_loss did not improve from 9.33037
# 551/551 [==============================] - 107s 194ms/step - loss: 7.3100 - val_loss: 9.4009 - lr: 0.0010
# Epoch 8/100
# 551/551 [==============================] - ETA: 0s - loss: 7.3758
# Epoch 8: val_loss did not improve from 9.33037
# 551/551 [==============================] - 104s 188ms/step - loss: 7.3758 - val_loss: 9.6360 - lr: 0.0010
# Epoch 9/100
# 551/551 [==============================] - ETA: 0s - loss: 7.4943
# Epoch 9: val_loss did not improve from 9.33037
# 551/551 [==============================] - 102s 186ms/step - loss: 7.4943 - val_loss: 9.5444 - lr: 0.0010
# Epoch 10/100
# 551/551 [==============================] - ETA: 0s - loss: 7.4203
# Epoch 10: val_loss improved from 9.33037 to 9.26041, saving model to ../output/bentham_v1/flor/bentham_train_polier_2.hdf5
# 551/551 [==============================] - 107s 195ms/step - loss: 7.4203 - val_loss: 9.2604 - lr: 0.0010
# Epoch 11/100
# 551/551 [==============================] - ETA: 0s - loss: 7.3282
# Epoch 11: val_loss did not improve from 9.26041
# 551/551 [==============================] - 108s 195ms/step - loss: 7.3282 - val_loss: 9.5963 - lr: 0.0010
# Epoch 12/100
# 551/551 [==============================] - ETA: 0s - loss: 7.3927
# Epoch 12: val_loss did not improve from 9.26041
# 551/551 [==============================] - 103s 187ms/step - loss: 7.3927 - val_loss: 9.2923 - lr: 0.0010
# Epoch 13/100
# 551/551 [==============================] - ETA: 0s - loss: 7.3416
# Epoch 13: val_loss did not improve from 9.26041
# 551/551 [==============================] - 102s 186ms/step - loss: 7.3416 - val_loss: 9.4960 - lr: 0.0010
# Epoch 14/100
# 551/551 [==============================] - ETA: 0s - loss: 7.3600
# Epoch 14: val_loss did not improve from 9.26041
# 551/551 [==============================] - 103s 186ms/step - loss: 7.3600 - val_loss: 9.5021 - lr: 0.0010
# Epoch 15/100
# 551/551 [==============================] - ETA: 0s - loss: 7.4686
# Epoch 15: val_loss did not improve from 9.26041
# 551/551 [==============================] - 107s 195ms/step - loss: 7.4686 - val_loss: 9.3971 - lr: 0.0010
# Epoch 16/100
# 551/551 [==============================] - ETA: 0s - loss: 7.3972
# Epoch 16: val_loss did not improve from 9.26041
# 551/551 [==============================] - 108s 195ms/step - loss: 7.3972 - val_loss: 9.5176 - lr: 0.0010
# Epoch 17/100
# 551/551 [==============================] - ETA: 0s - loss: 7.4601
# Epoch 17: val_loss did not improve from 9.26041
# 551/551 [==============================] - 103s 186ms/step - loss: 7.4601 - val_loss: 9.4026 - lr: 0.0010
# Epoch 18/100
# 551/551 [==============================] - ETA: 0s - loss: 7.4240
# Epoch 18: val_loss did not improve from 9.26041
# 551/551 [==============================] - 102s 186ms/step - loss: 7.4240 - val_loss: 9.9454 - lr: 0.0010
# Epoch 19/100
# 551/551 [==============================] - ETA: 0s - loss: 7.4621
# Epoch 19: val_loss did not improve from 9.26041
# 551/551 [==============================] - 103s 187ms/step - loss: 7.4621 - val_loss: 9.3829 - lr: 0.0010
# Epoch 20/100
# 551/551 [==============================] - ETA: 0s - loss: 7.3278
# Epoch 20: val_loss did not improve from 9.26041
# 551/551 [==============================] - 102s 185ms/step - loss: 7.3278 - val_loss: 9.4049 - lr: 0.0010
# Epoch 21/100
# 551/551 [==============================] - ETA: 0s - loss: 7.3690
# Epoch 21: val_loss did not improve from 9.26041
# 551/551 [==============================] - 103s 187ms/step - loss: 7.3690 - val_loss: 9.8448 - lr: 0.0010
# Epoch 22/100
# 551/551 [==============================] - ETA: 0s - loss: 7.3049
# Epoch 22: val_loss did not improve from 9.26041
# 551/551 [==============================] - 102s 186ms/step - loss: 7.3049 - val_loss: 9.5842 - lr: 0.0010
# Epoch 23/100
# 551/551 [==============================] - ETA: 0s - loss: 7.2683
# Epoch 23: val_loss did not improve from 9.26041
# 551/551 [==============================] - 101s 184ms/step - loss: 7.2683 - val_loss: 9.6342 - lr: 0.0010
# Epoch 24/100
# 551/551 [==============================] - ETA: 0s - loss: 7.3235
# Epoch 24: val_loss did not improve from 9.26041
# 551/551 [==============================] - 102s 186ms/step - loss: 7.3235 - val_loss: 9.6245 - lr: 0.0010
# Epoch 25/100
# 551/551 [==============================] - ETA: 0s - loss: 7.2780
# Epoch 25: val_loss did not improve from 9.26041
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# 551/551 [==============================] - 106s 193ms/step - loss: 5.2019 - val_loss: 8.4415 - lr: 2.0000e-04
# Epoch 40/100
# 551/551 [==============================] - ETA: 0s - loss: 5.1629
# Epoch 40: val_loss did not improve from 8.42072
# 551/551 [==============================] - 103s 187ms/step - loss: 5.1629 - val_loss: 8.5072 - lr: 2.0000e-04
# Epoch 41/100
# 551/551 [==============================] - ETA: 0s - loss: 5.0805
# Epoch 41: val_loss did not improve from 8.42072
# 551/551 [==============================] - 107s 195ms/step - loss: 5.0805 - val_loss: 8.5469 - lr: 2.0000e-04
# Epoch 42/100
# 551/551 [==============================] - ETA: 0s - loss: 5.1032
# Epoch 42: val_loss did not improve from 8.42072
# 551/551 [==============================] - 107s 194ms/step - loss: 5.1032 - val_loss: 8.5501 - lr: 2.0000e-04
# Epoch 43/100
# 551/551 [==============================] - ETA: 0s - loss: 5.0924
# Epoch 43: val_loss did not improve from 8.42072
# 551/551 [==============================] - 107s 193ms/step - loss: 5.0924 - val_loss: 8.5995 - lr: 2.0000e-04
# Epoch 44/100
# 551/551 [==============================] - ETA: 0s - loss: 5.0830
# Epoch 44: val_loss did not improve from 8.42072
# 551/551 [==============================] - 102s 186ms/step - loss: 5.0830 - val_loss: 8.5469 - lr: 2.0000e-04
# Epoch 45/100
# 551/551 [==============================] - ETA: 0s - loss: 4.9556
# Epoch 45: val_loss did not improve from 8.42072
# 551/551 [==============================] - 102s 185ms/step - loss: 4.9556 - val_loss: 8.6933 - lr: 2.0000e-04
# Epoch 46/100
# 551/551 [==============================] - ETA: 0s - loss: 4.9792
# Epoch 46: val_loss did not improve from 8.42072
# 551/551 [==============================] - 107s 194ms/step - loss: 4.9792 - val_loss: 8.6088 - lr: 2.0000e-04
# Epoch 47/100
# 551/551 [==============================] - ETA: 0s - loss: 4.9946
# Epoch 47: val_loss did not improve from 8.42072
# 551/551 [==============================] - 103s 187ms/step - loss: 4.9946 - val_loss: 8.5159 - lr: 2.0000e-04
# Epoch 48/100
# 551/551 [==============================] - ETA: 0s - loss: 4.9864
# Epoch 48: val_loss did not improve from 8.42072
# 551/551 [==============================] - 107s 194ms/step - loss: 4.9864 - val_loss: 8.4845 - lr: 2.0000e-04
# Epoch 49/100
# 551/551 [==============================] - ETA: 0s - loss: 4.9333
# Epoch 49: val_loss improved from 8.42072 to 8.32592, saving model to ../output/bentham_v1/flor/bentham_train_polier_2.hdf5
# 551/551 [==============================] - 103s 187ms/step - loss: 4.9333 - val_loss: 8.3259 - lr: 2.0000e-04
# Epoch 50/100
# 551/551 [==============================] - ETA: 0s - loss: 4.8757
# Epoch 50: val_loss did not improve from 8.32592
# 551/551 [==============================] - 103s 187ms/step - loss: 4.8757 - val_loss: 8.5444 - lr: 2.0000e-04
# Epoch 51/100
# 551/551 [==============================] - ETA: 0s - loss: 4.9074
# Epoch 51: val_loss improved from 8.32592 to 8.29245, saving model to ../output/bentham_v1/flor/bentham_train_polier_2.hdf5
# 551/551 [==============================] - 108s 197ms/step - loss: 4.9074 - val_loss: 8.2924 - lr: 2.0000e-04
# Epoch 52/100
# 551/551 [==============================] - ETA: 0s - loss: 4.9646
# Epoch 52: val_loss did not improve from 8.29245
# 551/551 [==============================] - 102s 186ms/step - loss: 4.9646 - val_loss: 8.4633 - lr: 2.0000e-04
# Epoch 53/100
# 551/551 [==============================] - ETA: 0s - loss: 4.9405
# Epoch 53: val_loss did not improve from 8.29245
# 551/551 [==============================] - 106s
# Restoring model weights from the end of the best epoch: 51.
# 551/551 [==============================] - 107s 194ms/step - loss: 4.3779 - val_loss: 8.3667 - lr: 4.0000e-05
# Epoch 71: early stopping
# Total train images:      8807
# Total validation images: 1372
# Batch:                   16
#
# Total time:              2:04:14.447891
# Time per epoch:          0:01:44.992224
# Time per item:           0:00:00.010315
#
# Total epochs:            71
# Best epoch               51
#
# Training loss:           4.90742588
# Validation loss:         8.29244900

# %% [markdown]
# ## 5 Predict

# %% [markdown]
# The predict process is similar to the *predict* of the Keras:

# %%
from data import preproc as pp
from google.colab.patches import cv2_imshow

start_time = datetime.datetime.now()

# predict() function will return the predicts with the probabilities
predicts, _ = model.predict(x=dtgen.next_test_batch(),
                            steps=dtgen.steps['test'],
                            ctc_decode=True,
                            verbose=1)

# decode to string
predicts = [dtgen.tokenizer.decode(x[0]) for x in predicts]
ground_truth = [x.decode() for x in dtgen.dataset['test']['gt']]

total_time = datetime.datetime.now() - start_time

# mount predict corpus file
with open(os.path.join(output_path, f"predict_{source}.txt"), "w") as lg:
    for pd, gt in zip(predicts, ground_truth):
        lg.write(f"TE_L {gt}\nTE_P {pd}\n")
   
for i, item in enumerate(dtgen.dataset['test']['dt'][:10]):
    print("=" * 1024, "\n")
    cv2_imshow(pp.adjust_to_see(item))
    print(ground_truth[i])
    print(predicts[i], "\n")
# Out:
# Model Predict
# 52/52 [==============================] - 5s 55ms/step
# CTC Decode
#  1/52 [..............................] - ETA: 1:11
# /usr/local/lib/python3.9/dist-packages/numpy/core/fromnumeric.py:43: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   result = getattr(asarray(obj), method)(*args, **kwds)
# 52/52 [==============================] - 76s 1s/step
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7F004BE50D60>
# brain.
# brain .
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7F006DE8E9A0>
# From this review then it appears, that
# From this recview then it appears that
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7F006DE8E9A0>
# in paving the way to the consideration of
# in paving hewag to the conple ralin 9
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7F006DE8E9A0>
# municipal Law, our Author has spent
# muniarpal Law , our Author ba' s pant
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7F006DE8E9A0>
# supposed
# suppored)
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7F006DE8E9A0>
# much time in explaining the nature &
# onuet time in esplaining the patise &
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7F006DE8E9A0>
# Properties of Laws which do not exist &
# Pn perties of Laws whic h do nob exisl . e
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7F006DE8E9A0>
# in misapplying those which do: & therefore,
# in misapplying those which do : & herefore
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7F006DE8E9A0>
# that the best thing which a Student of the
# pat he best thing which a Indenl of ue
#
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# <PIL.Image.Image image mode=L size=1024x128 at 0x7F006DE8E9A0>
# Law can do is to forget all that our Author
# Law cando is to forget all thal ourlathor

# %% [markdown]
# ## 6 Evaluate

# %% [markdown]
# Evaluation process is more manual process. Here we have the `ocr_metrics`, but feel free to implement other metrics instead. In the function, we have three parameters:
#
# * predicts
# * ground_truth
# * norm_accentuation (calculation with/without accentuation)
# * norm_punctuation (calculation with/without punctuation marks)

# %%
from data import evaluation

evaluate = evaluation.ocr_metrics(predicts, ground_truth)

e_corpus = "\n".join([
    f"Total test images:    {dtgen.size['test']}",
    f"Total time:           {total_time}",
    f"Time per item:        {total_time / dtgen.size['test']}\n",
    f"Metrics:",
    f"Character Error Rate: {evaluate[0]:.8f}",
    f"Word Error Rate:      {evaluate[1]:.8f}",
    f"Sequence Error Rate:  {evaluate[2]:.8f}"
])

with open(os.path.join(output_path, "evaluate.txt"), "w") as lg:
    lg.write(e_corpus)
    print(e_corpus)
# Out:
# Total test images:    820
# Total time:           0:01:20.392534
# Time per item:        0:00:00.098040
#
# Metrics:
# Character Error Rate: 0.07383662
# Word Error Rate:      0.31908942
# Sequence Error Rate:  0.79512195
